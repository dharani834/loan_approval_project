# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\dhara\Downloads\archive (12)\loan_approval_dataset.csv")
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.drop("loan_id", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0    no_of_dependents          4269 non-null   int64
#  1    education                 4269 non-null   object
#  2    self_employed             4269 non-null   object
#  3    income_annum              4269 non-null   int64
#  4    loan_amount               4269 non-null   int64
#  5    loan_term                 4269 non-null   int64
#  6    cibil_score               4269 non-null   int64
#  7    residential_assets_value  4269 non-null   int64
#  8    commercial_assets_value   4269 non-null   int64
#  9    luxury_assets_value       4269 non-null   int64
#  10   bank_asset_value          4269 non-null   int64
#  11   loan_status               4269 non-null   object
# dtypes: int64(9), object(3)
# memory usage: 400.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %%
df["self_employed"]=df["self_employed"].str.strip()
df["self_employed"]=df["self_employed"].replace({"No":0,"Yes":1})
# Out:
# C:\Users\dhara\AppData\Local\Temp\ipykernel_14332\209468230.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["self_employed"]=df["self_employed"].replace({"No":0,"Yes":1})

# %%
df.head()
# Out:
#    no_of_dependents      education  self_employed  income_annum  loan_amount  \
# 0                 2       Graduate              0       9600000     29900000
# 1                 0   Not Graduate              1       4100000     12200000
# 2                 3       Graduate              0       9100000     29700000
# 3                 3       Graduate              0       8200000     30700000
# 4                 5   Not Graduate              1       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
# ...

# %%
df["education"]=df["education"].str.strip()
df["education"]=df["education"].replace({"Not Graduate":0,"Graduate":1})
# Out:
# C:\Users\dhara\AppData\Local\Temp\ipykernel_14332\1381375543.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["education"]=df["education"].replace({"Not Graduate":0,"Graduate":1})

# %%
df.head()
# Out:
#    no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                 2          1              0       9600000     29900000
# 1                 0          0              1       4100000     12200000
# 2                 3          1              0       9100000     29700000
# 3                 3          1              0       8200000     30700000
# 4                 5          0              1       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value loan_status
# ...

# %%
df["loan_status"]=df["loan_status"].str.strip()
df["loan_status"]=df["loan_status"].replace({"Rejected":0,"Approved":1})
# Out:
# C:\Users\dhara\AppData\Local\Temp\ipykernel_14332\2932049452.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["loan_status"]=df["loan_status"].replace({"Rejected":0,"Approved":1})

# %%
df.head()
# Out:
#    no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                 2          1              0       9600000     29900000
# 1                 0          0              1       4100000     12200000
# 2                 3          1              0       9100000     29700000
# 3                 3          1              0       8200000     30700000
# 4                 5          0              1       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value  loan_status
# ...

# %%
df.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %%
sns.countplot(x="education",hue="loan_status",data=df)
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
df["loan_status"].value_counts()
# Out:
# loan_status
# 1    2656
# 0    1613
# Name: count, dtype: int64

# %%
ax=sns.barplot(x="self_employed",y="loan_status",data=df)
for a in ax.containers:
    ax.bar_label(a)

# %%
sns.boxplot(y="income_annum",x="loan_status",data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='income_annum'>

# %% [markdown]
# "The correlation analysis revealed that CIBIL score is the most influential feature affecting loan approval, exhibiting a strong positive correlation of 0.77 with the target variable.
# Loan term showed a weak negative correlation (-0.11), while all other features demonstrated negligible linear relationships with loan status.
# This suggests that creditworthiness, represented by the CIBIL score, plays a dominant role in the loan approval process within this dataset."

# %%
x=df.drop("loan_status",axis=1)
y=df["loan_status"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scale=scaler.fit_transform(x_train)
x_test_scale=scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(x_train_scale,y_train)
# Out:
# LogisticRegression()

# %%
y_predict=model.predict(x_test_scale)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print("confusion matrix",confusion_matrix(y_test,y_predict))
print("classification_report",classification_report(y_test,y_predict))
# Out:
# confusion matrix [[429  55]
#  [ 48 749]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89       484
#            1       0.93      0.94      0.94       797
#
#     accuracy                           0.92      1281
#    macro avg       0.92      0.91      0.91      1281
# weighted avg       0.92      0.92      0.92      1281

# %%
from sklearn.tree import DecisionTreeClassifier
model1=DecisionTreeClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model1.predict(x_test)

# %%
print("confusion matrix",confusion_matrix(y_test,y_pred))
print("classification_report",classification_report(y_test,y_pred))
# Out:
# confusion matrix [[470  14]
#  [ 13 784]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       484
#            1       0.98      0.98      0.98       797
#
#     accuracy                           0.98      1281
#    macro avg       0.98      0.98      0.98      1281
# weighted avg       0.98      0.98      0.98      1281

# %%
print("Train Accuracy:", model1.score(x_train, y_train))
print("Test Accuracy:", model1.score(x_test, y_test))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.9789227166276346

# %%
import pickle
with open("loan_approval_model.pkl","wb")as file:
    pickle.dump(model,file)

# %%
with open("loan_approval_model.pkl","rb")as file:
    model_load=pickle.load(file)

# %%
new_data = [[
    2,      # no_of_dependents
    1,      # education
    0,      # self_employed
    500000, # income_annum
    2000000,# loan_amount
    10,     # loan_term
    750,    # cibil_score
    3000000,# residential_assets_value
    1000000,# commercial_assets_value
    500000, # luxury_assets_value
    700000  # bank_asset_value
]]

# %%
prediction=model_load.predict(new_data)
if prediction[0]==1:
    print("approval")
else:
    print("rejected")
# Out:
# approval
